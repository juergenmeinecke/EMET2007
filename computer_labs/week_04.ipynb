# %% [markdown]
# # EMET2007 Week 4: Introduction to Simple Linear Regression
#
# ## Learning Objectives
#
# By the end of this tutorial, you will be able to:
# 1. Formulate a research question as a regression problem
# 2. Conduct a two-sample t-test to compare group means
# 3. Estimate a simple linear regression using OLS in Python
# 4. Interpret regression output (coefficients, standard errors, R-squared)
# 5. Visualise the estimated regression line on a scatter plot
# 6. Use the estimated model to make predictions
#
# ---
#
# ## Research Question
#
# **Do tall people earn more?**
#
# Before we begin, think about:
# - What would be your null hypothesis?
# - What economic mechanisms might explain a relationship between height and earnings?
# - Could there be confounding factors?
#
# ---
#
# ## Data Description
#
# We'll use the Earnings_and_Height dataset collected in the U.S. Since heights are measured in inches, here's a conversion reference:
#
# | Height (inches) | Height (cm) |
# |:----------------|:------------|
# | 65 | 165 |
# | 67 | 170 |
# | 70 | 178 |

# %% [markdown]
# ---
#
# ## Setup: Imports and Data Loading
#
# This week we add two new libraries:
# - `statsmodels.stats.api` - for statistical tests
# - `statsmodels.formula.api` - for regression models (using R-style formulas)
#
# and also the stats functions from the `scipy` library

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
from scipy import stats

# %%
df = pd.read_csv('https://raw.githubusercontent.com/juergenmeinecke/EMET2007/refs/heads/main/datasets/earnings_and_height.csv')

# %% [markdown]
# ---
#
# ## Part 1: Exploring the Data
#
# ### Exercise 1: Get to Know the Data
#
# Before running any analysis, always explore your data first.
#
# **Task:** Use `head()`, `tail()`, and `describe()` to understand:
# - How many observations are there?
# - What variables are included?
# - What are the ranges and distributions of key variables?

# %%
# View the first few rows

# %%
# View the last few rows

# %%
# Get summary statistics

# %% [markdown]
# ### Exercise 2: Convert Height to Centimetres
#
# The height variable is in inches. Let's convert to centimetres for easier interpretation.
#
# **Conversion:** 1 inch = 2.54 cm
#
# **Task:** Create a new variable `heightcm` that stores height in centimetres.

# %%
# Create height in centimetres
# df['heightcm'] = ...

# %% [markdown]
# ### Exercise 3: Visualise the Height Distribution
#
# **Task:** Create descriptive statistics, a boxplot, and a histogram for `heightcm`.
#
# **Boxplot syntax:**
# ```python
# fig, ax = plt.subplots()
# ax.boxplot(df.variable)
# ax.set_ylabel('Label')
# plt.show()
# ```
#
# **Histogram syntax:**
# ```python
# fig, ax = plt.subplots()
# ax.hist(df.variable, bins=20, ec='black')
# ax.set_xlabel('Label')
# ax.set_ylabel('Frequency')
# plt.show()
# ```

# %%
# Summary statistics for heightcm

# %%
# Create a boxplot

# %%
# Create a histogram
# Hint: Use bins=np.arange(120, 220, 5) for consistent bin widths

# %% [markdown]
# ---
#
# ## Part 2: Comparing Group Means
#
# ### Exercise 4: Create a Height Indicator Variable
#
# Let's split the sample into two groups: people above median height vs. at or below median height.
#
# A **dummy variable** (also called an indicator variable) equals 1 if a condition is true, 0 otherwise.
#
# **Task:** Create a variable `habove` that equals 1 if `heightcm` exceeds the median height, 0 otherwise.
#
# *Hint: First find the median with `df.heightcm.median()`, then use:*
# ```python
# df['habove'] = (df.heightcm > median_value).astype(int)
# ```

# %%
# Find the median height

# Create the dummy variable

# %% [markdown]
# ### Exercise 5: Test for Earnings Difference Between Groups
#
# Is there a statistically significant difference in earnings between people above the median height and those at or below?
#
# Use a two-sample t-test to answer this question.
#
# Steps:
#
# 1. Separate earnings into two groups based on habove
# 2. Conduct a two-sample t-test using scipy.stats.ttest_ind()
# 3. Interpret the results

# %%
# Step 1: Separate earnings into two groups based on habove
#habove_group = df[df.habove == 1].earnings
#hbelow_group = ???

# Step 2: Conduct the t-test (Welch's t-test with unequal variances)
#t_stat, p_value = stats.ttest_ind(habove_group, hbelow_group, equal_var=False)

# Step 3: Print results
#print(f'Mean earnings (above median height): ${habove_group.mean():,.2f}')
#print(f'Mean earnings (at/below median height): ${hbelow_group.mean():,.2f}')
#print(f'Difference: ${habove_group.mean() - hbelow_group.mean():,.2f}')
#print(f't-statistic: {t_stat:.3f}')
#print(f'p-value: {p_value:.2e}')

# %% [markdown]
# ---
#
# ## Part 3: Simple Linear Regression
#
# ### Exercise 6: Scatter Plot
#
# Before running a regression, always visualise the relationship.
#
# **Task:** Create a scatter plot with `heightcm` on the x-axis and `earnings` on the y-axis.
#
# *Think about it: What pattern do you observe? Is there an unusual feature in the data?*

# %%
# Create scatter plot
# (remember: you learned the syntax in last week's lab)

# %% [markdown]
# ### Exercise 7: Estimate the Regression
#
# We'll use `statsmodels` to estimate:
#
# $$\text{earnings}_i = \beta_0 + \beta_1 \cdot \text{heightcm}_i + u_i$$
#
# The syntax uses R-style formulas:
#
# ```python
# formula = 'y ~ x'                              # Define the model
# model = smf.ols(formula, data=df)              # Create the model
# results = model.fit()                          # Fit the model
# results.summary()                              # View results
# ```
#
# #### Exercise 7a: Run the Regression
#
# **Task:** Estimate the regression and interpret the output.
#
# *Key questions:*
# - What is the estimated intercept ($\hat{\beta}_0$)? How do you interpret it?
# - What is the estimated slope ($\hat{\beta}_1$)? What does it mean?
# - Is the slope statistically significant?
# - What is the R-squared? What does it tell us?

# %%
# Define and estimate the regression model

# %% [markdown]
# #### Exercise 7b: Add the Regression Line to the Scatter Plot
#
# The Population Regression Function (PRF) is estimated as:
#
# $$\widehat{\text{earnings}} = \hat{\beta}_0 + \hat{\beta}_1 \cdot \text{heightcm}$$
#
# To plot it:
# 1. Create a range of x values: `x = np.linspace(min_height, max_height, 100)`
# 2. Calculate predicted y values: `y_pred = results.params[0] + results.params[1] * x`
# 3. Add to plot: `ax.plot(x, y_pred, color='red', linewidth=2)`
#
# **Task:** Create a scatter plot with the estimated regression line overlaid.

# %%
# Scatter plot with regression line
fig, ax = plt.subplots()

# Plot the data points
# ax.scatter(df.heightcm, df.earnings, marker='.', alpha=0.5)

# Add the regression line
# x = np.linspace(120, 220, 100)
# y_pred = results.params[0] + results.params[1] * x
# ax.plot(x, y_pred, color='red', linewidth=2, label='Estimated PRF')

# ax.set_xlabel('Height (cm)')
# ax.set_ylabel('Annual earnings ($)')
# ax.set_title('Earnings vs Height with Regression Line')
# ax.legend()

plt.show()

# %% [markdown]
# #### Exercise 7c: Make Predictions
#
# Use your estimated model to predict earnings for workers of specific heights.
#
# **Syntax:**
# ```python
# new_data = {'heightcm': [165, 170, 178]}
# results.predict(new_data)
# ```
#
# **Task:** Predict earnings for workers who are 165 cm, 170 cm, and 178 cm tall.

# %%
# Make predictions

# %% [markdown]
# *Interpretation: According to your model, how much more would a 178 cm person expect to earn compared to a 165 cm person?*

# %% [markdown]
# ---
#
# ## Exercise 8: Exporting Your Work (Important for Assignments!)
#
# Save your notebook and export it as an HTML file.
#
# ### Anaconda/Jupyter Users:
# File → Download as → HTML (.html)
#
# (now download somewhere onto your own computer)
#
# ### Google Colab Users:
# Run the command below (update the file path as needed):

# %%
# Colab users: update the path to match your Google Drive location
# from google.colab import drive
# drive.mount('/content/drive')
# !jupyter nbconvert --to html 'drive/MyDrive/EMET2007/notebooks/week_4.ipynb'

# %% [markdown]
# After exporting, open the HTML file to verify it contains all your code, output, and graphs.
#
# ---
#
# ## Summary
#
# In this tutorial, you learned how to:
#
# - Create dummy variables to split samples into groups
# - Conduct a two-sample t-test to compare group means
# - Estimate a simple linear regression using `statsmodels`
# - Interpret regression output: coefficients, standard errors, t-statistics, p-values, R-squared
# - Visualise the regression line on a scatter plot
# - Use the estimated model for prediction
#
# ### Key Findings
#
# The regression suggests that taller people do tend to earn more, with each additional cm of height associated with approximately $279 more in annual earnings. However, height explains only about 1% of the variation in earnings (R² = 0.011), suggesting many other factors are more important.
#
# ---
#
# ## Attribution
#
# This exercise is based on Empirical Exercise 4.2 of Stock and Watson, *Introduction to Econometrics*, 4th global edition.
