# %% [markdown]
# # EMET2007 Week 2: Introduction to Python and Jupyter Notebooks
#
# ## Learning Objectives
#
# By the end of this tutorial, you will be able to:
# 1. Navigate Jupyter Notebooks using keyboard shortcuts
# 2. Import Python packages and load data into a pandas DataFrame
# 3. Explore datasets using basic pandas methods (`head()`, `tail()`, `describe()`)
# 4. Calculate summary statistics for individual and multiple variables
# 5. Identify and count missing values in a dataset
#
# ## Tutorial Information
#
# The source data for this week's tutorial comes from the World Bank which keeps a database called *World Development Indicators*. The WDI database is updated each year in April and collects about 800 different economic variables for more than 150 countries. For example, the World Bank collects basic macroeconomic data on GDP and growth rates, as well as data such as land areas, population size and also data on the environment, corruption, political institutions, poverty and many more.
#
# I have pulled a few variables from the following website:
#
# https://databank.worldbank.org/source/world-development-indicators.
#
# Note: To make it slightly easier for us syntactically, I have changed the variable names to use `camelCase`.
#
# Here is a short table describing the included variables:
#
# | Variable | Description |
# |:--|:--|
# | `countryName` |      Name of country |
# | `countryCode` |       Abbreviation for country name    |
# | `incomeGroup` |       One of four categories (high, upper-middle, lower-middle, low) |
# | `region` |              One of seven geographical regions |
# | `GDP` |                Gross domestic product in 2019, (constant 2010 USD) |
# | `population` |          Total number of residents (regardless of legal status or citizenship) |
# | `landArea` |          Square kilometers |
# | `lifeExpecFem` |      Life expectancy at birth, female |
# | `lifeExpecMale` |     Life expectancy at birth, male |

# %% [markdown]
# ---
#
# ## Part 1: Setting Up Your Environment
#
# ### Importing pandas
#
# Before we can work with data, we need to import the `pandas` library. Pandas is the most widely-used Python package for data analysis and works seamlessly with other scientific computing packages.
#
# **Why `as pd`?** This is a convention that lets us type `pd` instead of `pandas` every time we use a function from this library. You'll see this pattern frequently in Python code.
#
# Run the cell below to import pandas:

# %%
import pandas as pd

# %% [markdown]
# ### Loading the Data
#
# Now we need to load our dataset. The `read_csv()` function reads a CSV file and converts it into a pandas DataFrame - think of this as a spreadsheet-like data structure.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/juergenmeinecke/EMET2007/refs/heads/main/datasets/world_bank_wdi.csv')

# %% [markdown]
# Question: Can you see where you are accessing the data from?
#
# Answer: You're reading in a csv-file (a type of spreadsheet) here that is stored on a Github cloud server (inside my EMET2007 project).

# %% [markdown]
# ---
#
# ## Part 2: Notebook Shortcuts
#
# Jupyter Notebooks have two modes:
# - **Command mode**: For navigating between cells (cells have a blue/grey border)
# - **Edit mode**: For editing cell contents (cells have a green border)
#
# ### Google Colab Shortcuts
#
# | Action | Shortcut |
# |:-------|:---------|
# | Enter Edit mode | `Enter` |
# | Run current cell | `Ctrl` + `Enter` |
# | Add cell below | `b` |
# | Add cell above | `a` |
# | Delete cell | `Ctrl` + `M` then `D` |
# | Find/replace | `Ctrl` + `H` |
# | Exit Edit mode | `Esc` |
#
# ### Anaconda/Jupyter Notebook Shortcuts
#
# | Action | Shortcut |
# |:-------|:---------|
# | Enter Edit mode | `Enter` |
# | Run current cell | `Ctrl` + `Enter` |
# | Add cell below | `b` |
# | Add cell above | `a` |
# | Convert to Markdown | `m` |
# | Convert to Code | `y` |
# | Delete cell | `dd` (press `d` twice) |
# | Undo cell deletion | `z` |
# | Cut/Copy/Paste | `x` / `c` / `v` |
# | Exit Edit mode | `Esc` |

# %% [markdown]
# ---
#
# ## Exercise 1: Practice with Notebook Shortcuts
#
# Get comfortable with these shortcuts by completing the following tasks:
#
# 1. Create a new **code cell** below and type: `# here is my code`
# 2. Create a new **Markdown cell** and type: `This is my text answer`
#
# *Hint: Use `b` to add a cell below, then `m` to convert it to Markdown (Jupyter) or use the menu in Colab.*

# %% [markdown]
# ---
#
# ## Part 3: Exploring Your Data
#
# Now that we've loaded our data into a DataFrame called `df`, let's explore it!

# %% [markdown]
# ### Exercise 2: View the DataFrame
#
# The simplest way to see your data is to just type the DataFrame's name.
#
# **Task:** Type `df` in the cell below and run it. What do you see?
#
# *Note: For large datasets, pandas will show a truncated view with `...` indicating hidden rows/columns.*

# %%
# Type df below and run the cell

# %% [markdown]
# ### Exercise 3: Preview the Data
#
# Looking at the entire DataFrame can be overwhelming. Two helpful methods:
# - `df.head()` - shows the **first 5 rows** (or specify a number: `df.head(10)`)
# - `df.tail()` - shows the **last 5 rows**
#
# **Task:** Use both methods to preview the beginning and end of the dataset.

# %%
# View the first few rows

# %%
# View the last few rows

# %% [markdown]
# ---
#
# ## Part 4: Summary Statistics
#
# Summary statistics help us understand the distribution of our data. The `describe()` method is your best friend for this.

# %% [markdown]
# ### Exercise 4a: Summarise Individual Variables
#
# To access a single column (variable), you can use either:
# - **Dot notation:** `df.columnName` (simpler, but doesn't work if column name has spaces)
# - **Bracket notation:** `df['columnName']` (more flexible, always works)
#
# **Task:** Get summary statistics for `population` and `GDP` using the `describe()` method.
#
# *Example:* `df.population.describe()` or `df['population'].describe()`

# %%
# Describe the population variable

# %%
# Describe the GDP variable

# %% [markdown]
# ### Exercise 4b: Summarise All Numeric Variables
#
# Typing `describe()` for each variable is tedious. Fortunately, calling `describe()` on the entire DataFrame automatically summarises all numeric columns.
#
# **Task:** Apply `describe()` to the entire DataFrame.

# %%
# Describe all numeric variables in the DataFrame

# %% [markdown]
# ### Exercise 4c: Summarise Selected Variables
#
# Sometimes you only want statistics for a subset of variables. You can select multiple columns by passing a list of column names:
#
# ```python
# df[['column1', 'column2', 'column3']].describe()
# ```
#
# Notice the **double brackets** `[[  ]]` - the inner brackets define a list of column names.
#
# **Task:** Get summary statistics for `population`, `GDP`, `lifeExpecMale`, and `lifeExpecFem`.

# %%
# Select specific columns and describe them
# Hint: You can create a list of column names first, or put them directly in the brackets

# %% [markdown]
# ---
#
# ## Exercise 5: Individual Summary Statistics
#
# While `describe()` gives you a comprehensive overview, sometimes you need just one statistic. Pandas provides methods for common statistics:
#
# | Method | What it calculates |
# |:-------|:-------------------|
# | `.mean()` | Arithmetic mean |
# | `.median()` | Median (50th percentile) |
# | `.std()` | Standard deviation |
# | `.var()` | Variance |
# | `.min()` | Minimum value |
# | `.max()` | Maximum value |
#
# **Task:** Calculate the mean, median, standard deviation, and variance of `lifeExpecMale`.
#
# *Note: Pandas automatically ignores missing values (NaN) when calculating statistics.*

# %%
# Calculate summary statistics for lifeExpecMale
# Try: df.lifeExpecMale.mean(), df.lifeExpecMale.median(), etc.

# %% [markdown]
# **Bonus:** You can format your output nicely using Python's f-strings:
#
# ```python
# mean_value = df.lifeExpecMale.mean()
# print(f'The mean life expectancy for males is {mean_value:.2f} years')
# ```

# %%
# Optional: Print formatted statistics

# %% [markdown]
# ---
#
# ## Exercise 6: Handling Missing Values
#
# Real-world data often has missing values. In pandas, missing values are represented as `NaN` (Not a Number).
#
# To find missing values:
# - `df.columnName.isnull()` - returns `True` for each missing value
# - `df.columnName.isnull().sum()` - counts the total missing values
#
# **Task:** Count how many missing values there are in the `lifeExpecMale` column.

# %%
# Count missing values in lifeExpecMale

# %% [markdown]
# **Think about it:** Why might some countries have missing values for life expectancy? How might this affect your analysis?

# %% [markdown]
# ---
#
# ## Summary
#
# In this tutorial, you learned how to:
#
# - Import pandas and load data from a CSV file
# - Navigate Jupyter Notebooks using keyboard shortcuts
# - Preview data using `head()` and `tail()`
# - Calculate summary statistics using `describe()`, `mean()`, `median()`, `std()`, and `var()`
# - Access individual columns using dot notation (`df.column`) or bracket notation (`df['column']`)
# - Count missing values using `isnull().sum()`
#
# ### Next Steps
#
# In next week's tutorial, we'll learn how to:
# - Filter and subset data
# - Create new variables
# - Group data and calculate group-level statistics
