# %% [markdown]
# # EMET2007 Week 5
#
# Continue your investigation of the association between earnings and heights from last week.
# Recall that the broad research question was: **Do tall people earn more?**
#
# # Imports and loading data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# df = pd.read_csv('drive/MyDrive/EMET2007/datasets/earnings_and_height.csv')

# %%
df = pd.read_csv('../datasets/earnings_and_height.csv')

# %% [markdown]
# ## Exercise 1
#
# Rerun the regression of ``earnings`` on ``heightcm`` from last week. This time we focus on hypothesis testing for $\beta_1$.
#
# Test the null hypothesis that $\beta_1 = 0$. Use three equivalent ways of testing this hypothesis:
#
# - via the t-statistic
# - via the confidence interval
# - via the p-value
#
# You can find the relevant information in the standard regression output.

# %% [markdown]
# ## Exercise 2
# Last week you studied the bivariate association between ``earnings`` and ``height``. You found that both are positively associated. Recall that the average annual earnings gap  between the two groups ``habove==0`` and ``habove==1`` was about \$5,500.
#
# ### Exercise 2a
# We want to explore if this gap should be taken at face value. That is, does height really **cause** earnings to increase by that amount? To do so, study the bivariate associations between
# - ``earnings`` and ``male``, and
# - ``heightcm`` and ``male``.
#
# (Use descriptive statistics to study these associations.)

# %% [markdown]
# ### Exercise 2b
# What do you learn here that helps you shape a more informed opinion about the causal effect of height on earnings?

# %% [markdown]
# **Put your answer here in this text cell**

# %% [markdown]
# ## Exercise 3
#
# ### Exercise 3a
# Run a regression of ``earnings`` on ``heightcm`` in two sub-samples:
# * females
# * males

# %% [markdown]
# ### Exercise 3b
#
# How does this address some of the lessons learned in the preceding exercise?

# %% [markdown]
# **Put your answers here in this text cell**

# %% [markdown]
# ## Exercise 4
#
# Run the regression of ``earnings`` on ``height`` where ``height`` is measured in inches instead of centimeters. How do intercept and slope estimate change compared to last week's exercise (in which you used heights measured in centimeters)?

# %% [markdown]
# **Put your answers here in this text cell**

# %% [markdown]
# ## Exercise 5: Important for Your Assignments!
#
# Save your current Jupyter notebook file named **week_5.ipynb**.
#
# Create an **html** file with the name **week_5.html** from your Jupyter notebook file **week_5.ipynb**.
#
# Depending on how you are using Jupyter (Colab or Anaconda), there are different ways of doing so:
#
# ### Anaconda users:
#
# Open the **File** menu at the top left of your browser and choose **Download as** and navigate your way through to saving the file as an **html** file.
#
# After saving the **html** file, convince yourself that it worked properly: open the file to see that it contains all your comments, code, and graphs!
#
# Let your tutor know if you are having any problems!
#
# ### Colab users:
#
# Execute the following line of code:

# %%
# make sure to change the file path to correspond to your own Google drive setup!
# !jupyter nbconvert --to html 'drive/MyDrive/EMET2007/notebooks/week_5.ipynb'

# %% [markdown]
# This single line command takes your Jupyter notebook file **week_5.ipynb** and creates the html file **week_5.html**. (The Jupyter notebook file will not be deleted in the process). This command requires you to:
#
# * call the current Jupyter notebook **week_5.ipynb**, no deviations in spelling, cases, and spaces;
# * update the file path to the location on your Google drive where you store the file **week_5.ipynb**
#
# After creating the html file in your Google drive, download it to your computer and see that it contains all your comments, code, and graphs!
#
# Let your tutor know if you are having any problems!

# %% [markdown]
# ## Attribution
# This exercise is based on Empirical Exercise 4.2 of Stock and Watson, *Introduction to Econometrics*, 4th global edition
