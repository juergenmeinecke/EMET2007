# %% [markdown]
# # EMET2007 Week 3
#
# Use last week's WDI data set from the World Bank to continue your ``Python`` learning journey. Today we will do more univariate descriptive analysis, explore basic data visualization commands, and we will get familiar with ``Python`` commands for bivariate descriptive analysis as a preparation for the simple regression model (which we will cover next week).

# %% [markdown]
# ## Imports and loading data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Remember:** Uncomment the appropriate cell below for your method of running notebooks.
#
# If you like, you can delete the cell that doesn't apply to your method of running notebooks.

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# df = pd.read_csv('drive/MyDrive/EMET2007/datasets/world_bank_wdi.csv')

# %%
df = pd.read_csv('../datasets/world_bank_wdi.csv')

# %% [markdown]
# ## Exercise 1
#
# Create a new variable *GDPpc* that stores countries' per capita GDP.

# %%
df['GDPpc'] = df.GDP / df.population  
# We have to use the [''] notation to create new variables

# %%
df.GDPpc.describe()
# Out:
# count       185.000000
# mean      15014.186928
# std       20520.320084
# min         208.074727
# 25%        1840.504353
# 50%        5922.527587
# 75%       17406.552080
# max      111062.340610
# Name: GDPpc, dtype: float64

# %% [markdown]
# ## Exercise 2
# How could you access Australia's per capita GDP? How about New Zealand and the United States?

# %%
df[df.countryName == 'Australia'].GDPpc
# Out:
# 10    57186.621293
# Name: GDPpc, dtype: float64

# %%
countries = ('Australia', 'New Zealand', 'United States')
anzus = df[df.countryName.isin(countries)]
anzus
# Out:
#        countryName countryCode  incomeGroup               region  \
# 10       Australia         AUS  High income  East Asia & Pacific
# 141    New Zealand         NZL  High income  East Asia & Pacific
# 206  United States         USA  High income        North America
#
#               GDP   population   landArea  lifeExpecFem  lifeExpecMale  \
# 10   1.450499e+12   25364307.0  7682300.0         84.50          80.40
# 141  1.917285e+11    4917000.0   263310.0         83.27          79.73
# 206  1.830039e+13  328239523.0  9147420.0         81.20          76.30
#
#             GDPpc
# 10   57186.621293
# 141  38992.974463
# 206  55753.144369

# %%
anzus[['countryName', 'GDPpc']]
# Out:
#        countryName         GDPpc
# 10       Australia  57186.621293
# 141    New Zealand  38992.974463
# 206  United States  55753.144369

# %% [markdown]
# ## Exercise 3
#
# ### Exercise 3a
# How about the average per capita GDP of countries in South Asia?

# %%
df[df.region == 'South Asia'].GDPpc.mean()
# Out:
# 2725.9700694296585

# %% [markdown]
# ### Exercise 3b
# What countries does this include? (When you consider subsets of the original data frame using a logical statement like here, then this is sometimes called *slicing the data set*).

# %%
df[df.region == 'South Asia'].countryName
# Out:
# 0      Afghanistan
# 15      Bangladesh
# 22          Bhutan
# 89           India
# 121       Maldives
# 138          Nepal
# 149       Pakistan
# 180      Sri Lanka
# Name: countryName, dtype: object

# %% [markdown]
# ## Exercise 4
#
# Which countries have female life expectancy larger than 85? Lower than 55?

# %%
df[df.lifeExpecFem > 85]
# Out:
#               countryName countryCode  incomeGroup                 region  \
# 68                 France         FRA  High income  Europe & Central Asia
# 86   Hong Kong SAR, China         HKG  High income    East Asia & Pacific
# 98                  Japan         JPN  High income    East Asia & Pacific
# 104           Korea, Rep.         KOR  High income    East Asia & Pacific
# 117      Macao SAR, China         MAC  High income    East Asia & Pacific
# 171             Singapore         SGP  High income    East Asia & Pacific
# 179                 Spain         ESP  High income  Europe & Central Asia
# 188           Switzerland         CHE  High income  Europe & Central Asia
#
#               GDP   population       landArea  lifeExpecFem  lifeExpecMale  \
# 68   2.971919e+12   67059887.0  547556.992188        85.600         79.200
# 86   2.847433e+11    7507400.0    1050.000000        87.300         81.400
# 98   6.210698e+12  126264931.0  364560.000000        86.990         80.750
# 104  1.482760e+12   51709098.0   97445.000000        85.200         79.000
# 117  3.529525e+10     640445.0      30.400000        86.631         80.718
# 171  3.355389e+11    5703569.0     709.000015        85.100         80.500
# 179  1.572013e+12   47076781.0  499661.015625        85.700         80.100
# 188  6.808987e+11    8574832.0   39516.000977        85.100         80.800
#
#             GDPpc
# 68   44317.392305
# 86   37928.353330
# 98   49187.833090
# 104  28675.034407
# 117  55110.513950
# 171  58829.635370
# 179  33392.527360
# 188  79406.657667

# %%
df[df.lifeExpecFem < 55]
# Out:
#                   countryName countryCode          incomeGroup  \
# 37   Central African Republic         CAF           Low income
# 38                       Chad         TCD           Low income
# 111                   Lesotho         LSO  Lower middle income
# 144                   Nigeria         NGA  Lower middle income
# 170              Sierra Leone         SLE           Low income
#
#                  region           GDP   population   landArea  lifeExpecFem  \
# 37   Sub-Saharan Africa  1.822842e+09    4745185.0   622980.0        52.793
# 38   Sub-Saharan Africa  1.297629e+10   15946876.0  1259200.0        54.552
# 111  Sub-Saharan Africa  2.874586e+09    2125268.0    30360.0        54.266
# 144  Sub-Saharan Africa  4.771618e+11  200963599.0   910770.0        53.967
# 170  Sub-Saharan Africa  3.816411e+09    7813215.0    72180.0        53.770
#
#      lifeExpecMale        GDPpc
# 37          48.985   384.145562
# 38          51.743   813.719895
# 111         47.979  1352.575618
# 144         52.286  2374.369430
# 170         52.068   488.455874

# %% [markdown]
# <br><br>
#
# So far we have limited ourselves to **univariate** descriptive analysis. Now we will do **bivariate** descriptive analysis, studying the relationship between two variables. We need to distinguish three cases:
#
# * two categorical variables
# * one categorical and one numerical variable
# * two numerical variables
#
# ## Exercise 5
#
# The association between two categorical variables is typically presented in a contingency table. Use ``pandas``' ``crosstab`` function to study the association between region and income group.  Also explore the `normalize` argument of this function.

# %%
# ?pd.crosstab

# %%
pd.crosstab(df.region, df.incomeGroup, margins = True)
# Out:
# incomeGroup                 High income  Low income  Lower middle income  \
# region
# East Asia & Pacific                  14           1                   12
# Europe & Central Asia                38           1                    4
# Latin America & Caribbean            17           1                    4
# Middle East & North Africa            8           2                    6
# North America                         3           0                    0
# South Asia                            0           1                    6
# Sub-Saharan Africa                    2          23                   18
# All                                  82          29                   50
#
# incomeGroup                 Upper middle income  All
# region
# East Asia & Pacific                          10   37
# Europe & Central Asia                        15   58
# Latin America & Caribbean                    20   42
# Middle East & North Africa                    5   21
# North America                                 0    3
# South Asia                                    1    8
# Sub-Saharan Africa                            5   48
# All                                          56  217

# %%
pd.crosstab(df.region, df.incomeGroup, margins = True, normalize = True)
# add "* 100" on the end to get percentages instead of proportions
# Out:
# incomeGroup                 High income  Low income  Lower middle income  \
# region
# East Asia & Pacific            0.064516    0.004608             0.055300
# Europe & Central Asia          0.175115    0.004608             0.018433
# Latin America & Caribbean      0.078341    0.004608             0.018433
# Middle East & North Africa     0.036866    0.009217             0.027650
# North America                  0.013825    0.000000             0.000000
# South Asia                     0.000000    0.004608             0.027650
# Sub-Saharan Africa             0.009217    0.105991             0.082949
# All                            0.377880    0.133641             0.230415
#
# incomeGroup                 Upper middle income       All
# region
# East Asia & Pacific                    0.046083  0.170507
# Europe & Central Asia                  0.069124  0.267281
# Latin America & Caribbean              0.092166  0.193548
# Middle East & North Africa             0.023041  0.096774
# North America                          0.000000  0.013825
# South Asia                             0.004608  0.036866
# Sub-Saharan Africa                     0.023041  0.221198
# All                                    0.258065  1.000000

# %% [markdown]
# ## Exercise 6
#
# We can group the observations in the dataset by a categorical variable using the `groupby` function.  We can then use this grouping to explore the association between a categorical and a numerical variable.  Explore the association between per capita GDP and income group.

# %%
df.groupby('incomeGroup').GDPpc.describe()
# Out:
#                      count          mean           std          min  \
# incomeGroup
# High income           62.0  36824.817602  22838.262700  8222.941885
# Low income            24.0    718.426717    292.544737   208.074727
# Lower middle income   48.0   2319.697115   1095.219000   859.023683
# Upper middle income   51.0   7174.474265   2592.571671  3325.807810
#
#                               25%           50%           75%            max
# incomeGroup
# High income          17447.991722  30651.559200  50263.988306  111062.340610
# Low income             521.766586    633.506794    841.979027    1513.178958
# Lower middle income   1387.685308   1983.264277   3068.030821    4818.192165
# Upper middle income   5153.878466   6678.509065   8824.217362   15125.391121

# %% [markdown]
# ## Exercise 7
# The association between two numerical variables can be condensed in two popular measures: covariance and correlation. Remember that these measures only summarize the **linear** association between two variables. Calculate the covariance and correlation between per capita GDP and female life expectancy at birth. Do they seem strongly associated?

# %%
df[['GDPpc', 'lifeExpecFem']].cov()
# Out:
#                      GDPpc   lifeExpecFem
# GDPpc         4.210835e+08  106717.227885
# lifeExpecFem  1.067172e+05      67.494962

# %%
df[['GDPpc', 'lifeExpecFem']].corr()
# Out:
#                  GDPpc  lifeExpecFem
# GDPpc         1.000000      0.625464
# lifeExpecFem  0.625464      1.000000

# %% [markdown]
# **Interpretation:** A correlation coefficient of 0.625464 implies a moderate positive correlation between the two variables.

# %% [markdown]
# ## Exercise 8
# Now generate a scatter plot of these two variables. Does the relationship between per capita GDP and female life expectancy at birth appear linear? Do they seem strongly associated?

# %%
fig, ax = plt.subplots()

ax.plot(df.GDPpc, df.lifeExpecFem, '.', c='darkgreen')
ax.set_xlabel('GDP per capita ($)')
ax.set_ylabel('Life expectancy (years)')
ax.set_title('Per capita GDP vs female life expectancy at birth')
plt.show()

# %% [markdown]
# **Interpretation:** Association seems strong, but relationship does not appear linear.
